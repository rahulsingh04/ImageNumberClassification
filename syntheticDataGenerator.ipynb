# %% [markdown]
# ### Synthetic Data Generator For The  Numerical Image From 1 to 100

# %%
import os
import cv2
import numpy as np
from PIL import Image, ImageDraw, ImageFont
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def draw_text(image, text, position, font_size=32, color=(0, 0, 0)):
    """
    Draw text on an image.

    Args:
        image (PIL.Image.Image): The input image.
        text (str): The text to draw on the image.
        position (tuple): The position (x, y) to draw the text.
        font_size (int, optional): The font size. Defaults to 32.
        color (tuple, optional): The color of the text. Defaults to (0, 0, 0).

    Returns:
        PIL.Image.Image: The image with the text drawn on it.
    """
    font = ImageFont.truetype("arial.ttf", font_size)
    draw = ImageDraw.Draw(image)
    draw.text(position, text, color, font=font)
    return image

def generate_dataset(output_folder, num_images_per_number=300):
    """
    Generate a dataset of images containing numbers.

    Args:
        output_folder (str): The folder where the dataset will be saved.
        num_images_per_number (int, optional): The number of images to generate for each number. Defaults to 300.
    """
    os.makedirs(output_folder, exist_ok=True)
    
    # Define image data generator with augmentation parameters
    data_gen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.1,
        height_shift_range=0.1,
        brightness_range=(0.7, 1.3),
        shear_range=10,
        zoom_range=0.1,
        channel_shift_range=20,
        fill_mode='nearest',
        horizontal_flip=True,
        vertical_flip=True,
    )
    
    # Loop through numbers 1 to 100
    for i in range(1, 101):
        number_folder = os.path.join(output_folder, str(i))
        os.makedirs(number_folder, exist_ok=True)
        
        # Generate specified number of images for each number
        for j in range(1, num_images_per_number + 1):  
            # Generate image with the current number
            image = Image.new("L", (100, 50), color=255)
            image = draw_text(image, str(i), (10, 10), color=0)
            
            # Reshape image for ImageDataGenerator
            image_array = np.array(image).reshape((1, 50, 100, 1))
            
            # Apply augmentation and save the image
            augmented_images = data_gen.flow(image_array, batch_size=1)
            augmented_image = augmented_images.next()[0].astype(np.uint8)
            
            augmented_image_path = os.path.join(number_folder, f"image_{j}.png")
            cv2.imwrite(augmented_image_path, augmented_image[:,:,0])  
            
        print(f"Images in folder {number_folder} created successfully.")

    print("Dataset generated successfully.")

# %%
# Example usage:
output_folder = "Number_Images"
num_images_per_number = 300
generate_dataset(output_folder, num_images_per_number)
# Out:
# Images in folder Number_Images\1 created successfully.
# Images in folder Number_Images\2 created successfully.
# Images in folder Number_Images\3 created successfully.
# Images in folder Number_Images\4 created successfully.
# Images in folder Number_Images\5 created successfully.
# Images in folder Number_Images\6 created successfully.
# Images in folder Number_Images\7 created successfully.
# Images in folder Number_Images\8 created successfully.
# Images in folder Number_Images\9 created successfully.
# Images in folder Number_Images\10 created successfully.
# Images in folder Number_Images\11 created successfully.
# Images in folder Number_Images\12 created successfully.
# Images in folder Number_Images\13 created successfully.
# Images in folder Number_Images\14 created successfully.
# Images in folder Number_Images\15 created successfully.
# Images in folder Number_Images\16 created successfully.
# Images in folder Number_Images\17 created successfully.
# Images in folder Number_Images\18 created successfully.
# Images in folder Number_Images\19 created successfully.
# Images in folder Number_Images\20 created successfully.
# Images in folder Number_Images\21 created successfully.
# Images in folder Number_Images\22 created successfully.
# Images in folder Number_Images\23 created successfully.
# Images in folder Number_Images\24 created successfully.
# Images in folder Number_Images\25 created successfully.
# Images in folder Number_Images\26 created successfully.
# Images in folder Number_Images\27 created successfully.
# Images in folder Number_Images\28 created successfully.
# Images in folder Number_Images\29 created successfully.
# Images in folder Number_Images\30 created successfully.
# Images in folder Number_Images\31 created successfully.
# Images in folder Number_Images\32 created successfully.
# Images in folder Number_Images\33 created successfully.
# Images in folder Number_Images\34 created successfully.
# Images in folder Number_Images\35 created successfully.
# Images in folder Number_Images\36 created successfully.
# Images in folder Number_Images\37 created successfully.
# Images in folder Number_Images\38 created successfully.
# Images in folder Number_Images\39 created successfully.
# Images in folder Number_Images\40 created successfully.
# Images in folder Number_Images\41 created successfully.
# Images in folder Number_Images\42 created successfully.
# Images in folder Number_Images\43 created successfully.
# Images in folder Number_Images\44 created successfully.
# Images in folder Number_Images\45 created successfully.
# Images in folder Number_Images\46 created successfully.
# Images in folder Number_Images\47 created successfully.
# Images in folder Number_Images\48 created successfully.
# Images in folder Number_Images\49 created successfully.
# Images in folder Number_Images\50 created successfully.
# Images in folder Number_Images\51 created successfully.
# Images in folder Number_Images\52 created successfully.
# Images in folder Number_Images\53 created successfully.
# Images in folder Number_Images\54 created successfully.
# Images in folder Number_Images\55 created successfully.
# Images in folder Number_Images\56 created successfully.
# Images in folder Number_Images\57 created successfully.
# Images in folder Number_Images\58 created successfully.
# Images in folder Number_Images\59 created successfully.
# Images in folder Number_Images\60 created successfully.
# Images in folder Number_Images\61 created successfully.
# Images in folder Number_Images\62 created successfully.
# Images in folder Number_Images\63 created successfully.
# Images in folder Number_Images\64 created successfully.
# Images in folder Number_Images\65 created successfully.
# Images in folder Number_Images\66 created successfully.
# Images in folder Number_Images\67 created successfully.
# Images in folder Number_Images\68 created successfully.
# Images in folder Number_Images\69 created successfully.
# Images in folder Number_Images\70 created successfully.
# Images in folder Number_Images\71 created successfully.
# Images in folder Number_Images\72 created successfully.
# Images in folder Number_Images\73 created successfully.
# Images in folder Number_Images\74 created successfully.
# Images in folder Number_Images\75 created successfully.
# Images in folder Number_Images\76 created successfully.
# Images in folder Number_Images\77 created successfully.
# Images in folder Number_Images\78 created successfully.
# Images in folder Number_Images\79 created successfully.
# Images in folder Number_Images\80 created successfully.
# Images in folder Number_Images\81 created successfully.
# Images in folder Number_Images\82 created successfully.
# Images in folder Number_Images\83 created successfully.
# Images in folder Number_Images\84 created successfully.
# Images in folder Number_Images\85 created successfully.
# Images in folder Number_Images\86 created successfully.
# Images in folder Number_Images\87 created successfully.
# Images in folder Number_Images\88 created successfully.
# Images in folder Number_Images\89 created successfully.
# Images in folder Number_Images\90 created successfully.
# Images in folder Number_Images\91 created successfully.
# Images in folder Number_Images\92 created successfully.
# Images in folder Number_Images\93 created successfully.
# Images in folder Number_Images\94 created successfully.
# Images in folder Number_Images\95 created successfully.
# Images in folder Number_Images\96 created successfully.
# Images in folder Number_Images\97 created successfully.
# Images in folder Number_Images\98 created successfully.
# Images in folder Number_Images\99 created successfully.
# Images in folder Number_Images\100 created successfully.
# Dataset generated successfully.
